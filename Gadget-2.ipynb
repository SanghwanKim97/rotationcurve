# %%
from pygadgetreader import *
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
K=13
plt.figure(figsize=(15,10))
for i in range(0,10) :
    X=i
    a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_00{0}'.format(X), 'pos', 'disk')
    plt.xlim(-50,50)
    plt.ylim(-50,50)
    plt.xlabel('X (kpc)')
    plt.ylabel('Velocity (km/s)', rotation=360, labelpad=40)
    plt.plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')
    a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_00{0}'.format(X), 'pos', 'bulge')
    #plt.plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')
    #a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output14/snapshot_00%d'%X, 'pos', 'dm')
    #plt.plot(a[0:,0],a[0:,1], 'k,')
    plt.savefig('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/figure00{0}.png'.format(X))
    plt.clf() #plot clean should be done in order to take another picture
for i in range(10, 100) :
    X=i
    a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_0{0}'.format(X), 'pos', 'disk')
    plt.xlim(-50,50)
    plt.ylim(-50,50)
    plt.xlabel('X (kpc)')
    plt.ylabel('Velocity (km/s)', rotation=360, labelpad=40)
    plt.plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')
    #a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_0{0}'.format(X), 'pos', 'bulge')
    plt.plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')
    #a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output14/snapshot_0%d'%X, 'pos', 'dm')
    #plt.plot(a[0:,0],a[0:,1], 'k,')
    plt.savefig('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/figure0{0}.png'.format(X))
    plt.clf()
for i in range(100, 126) :
    X=i
    a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_{0}'.format(X), 'pos', 'disk')
    plt.xlim(-50,50)
    plt.ylim(-50,50)
    plt.xlabel('X (kpc)')
    plt.ylabel('Velocity (km/s)', rotation=360, labelpad=40)
    plt.plot(a[0:,0],a[0:,1], color='black', marker=',',linestyle='')
    #a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output{0}/snapshot_{1}'.format(K,X), 'pos', 'bulge')
    plt.plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')
    #a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output12/snapshot_%d'%X, 'pos', 'dm')
    #plt.plot(a[0:,0],a[0:,1], 'k,')
    plt.savefig('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/figure{0}.png'.format(X))
    plt.clf()
# Out:
# Could not determine file type by extension!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/M1-1nodm/snapshot_011', 'pos', 'disk')
b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/M1-1nodm/snapshot_011', 'pos', 'disk')
#a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'pos', 'disk')
#b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'vel', 'disk')
#c=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_006', 'pos', 'disk')
#d=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_006', 'vel', 'disk')
#plt.xlim(-5,100)
#plt.ylim(0,400)
#for i in range(0,100000):
 #   if a[i,0] > -10 and b[i,1] < 200:
  #      b[i,1]=0
#f, axes=plt.subplots(2,2)    
#plt.xlabel('x')
#plt.ylabel('V_y')
#axes[0,1].plt.plot(c[0:,0],d[0:,1], ',')
#for i in range(0,)
plt.plot(a[0:,0],a[0:,1], ',', color='black')
#plt.plot(c[0:,0],d[0:,1], ',')
#linear_model=np.polyfit(a[0:,0],b[0:,1], 3)
#linear_model_fn=np.poly1d(linear_model)
#x_s=np.arange(0,20)
#plt.plot(x_s,linear_model_fn(x_s), color="black")

# %%
#f, axes=plt.subplots(1,3)
#f.set_size_inches((10,4))
a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'pos', 'disk')
b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'vel', 'disk')
c=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'pos', 'disk')
d=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'vel', 'disk')
#axes[2].plot(a[0:,0],b[0:,1])
#a=sorted(a, key=lambda x:x[0])
#b=sorted(b, key=lambda x:x[1])
#a=np.array(a);
#b=np.array(b);
#axes[0].plot(a[0:,0],b[0:,1])

A=a[0:,0]
B=b[0:,1]
#print(A)
#print('\n')
#print(B)
N=np.arange(1,10)
M=np.arange(1,10)
MT=np.vstack((A,B))
#print(np.shape(MT))
MT=MT.T
#print('\n')
#print((MT[0:,0]))
X=sorted(MT, key=lambda x:x[0])
X=np.array(X)

C=c[0:,0]
D=d[0:,1]
MTR=np.vstack((C,D))
MTR=MTR.T
Y=sorted(MTR, key=lambda x:x[0])
Y=np.array(Y)

plt.figure(figsize=(10,5))
print('\n')
#print(X[0:100,0:100]) #sotred position and velocity(x-V_y) data set
for i in range(0,100000, 100):
    averagex=np.mean(X[i:i+100,0]+15)
    averagey=np.mean(X[i:i+100,1])/2
    plt.plot(averagex, averagey, marker='.', color='black')
    plt.xlabel('X (kpc)')
    plt.ylabel('Velocity (km/s)', rotation=360, labelpad=40)
    averageX=np.mean(Y[i:i+100,0]+10)/5
    averageY=np.mean(Y[i:i+100,1])/2
    plt.ylim(0,150)
    plt.xlim(0,20)
    plt.plot(averageX, averageY, marker='.', linestyle='', color='red')
plt.plot(averageX, averageY, label='No Dark Matter', color='red', marker='.')
plt.plot(averagex, averagey, label='With Dark Matter', color='black', marker='.')
plt.legend()
#axes[0].plot(c[0:,0],d[0:,1])
#axes[0].set_xlim(-20,20)
#axes[0].set_ylim(0,400)
#a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'pos', 'disk')
#b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'vel', 'disk')
#c=sorted(a, key=lambda x:x[0])
#d=sorted(b, key=lambda x:x[0])
#c=np.array(c)
#d=np.array(b)    
#for i in range(0, 100000 ,100):
#    averagex=np.mean(c[0+i:i+100,0])
#    averagey=np.mean(d[0+i:i+100,1])
#axes[2].plot(a[0:,0],a[0:,1], color='black', marker=',', linestyle='')

# %%
#f, axes=plt.subplots(1,3)
#f.set_size_inches((10,4))
a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'pos', 'disk')
b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'vel', 'disk')
c=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'pos', 'disk')
d=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'vel', 'disk')

A=a[0:,0]
B=b[0:,1]

N=np.arange(1,10)
M=np.arange(1,10)
MT=np.vstack((A,B))

MT=MT.T

X=sorted(MT, key=lambda x:x[0])
X=np.array(X)

C=c[0:,0]
D=d[0:,1]
MTR=np.vstack((C,D))
MTR=MTR.T
Y=sorted(MTR, key=lambda x:x[0])
Y=np.array(Y)

plt.figure(figsize=(10,5))
averagex=np.zeros((100))
averagey=np.zeros((100))
averageX=np.zeros((100))
averageY=np.zeros((100))
j=0
print('\n')
for i in range(0,100000, 1000):
    averagex[j]=np.mean(X[i:i+1000,0]+14.6)
    averagey[j]=np.mean(X[i:i+1000,1])/1.7
    #plt.plot(averagex, averagey, marker='.', color='black')
    plt.xlabel('X (kpc)')
    plt.ylabel('Velocity (km/s)', rotation=360, labelpad=40)
    averageX[j]=np.mean(Y[i:i+1000,0]+7)/5
    averageY[j]=np.mean(Y[i:i+1000,1])/2
    plt.ylim(0,150)
    plt.xlim(0,20)
    j=j+1
    #plt.plot(averageX, averageY, marker='.', linestyle='', color='red')
plt.plot(averageX, averageY, label='No Dark Matter', color='red', marker='.', linestyle='solid')
plt.plot(averagex, averagey, label='With Dark Matter', color='black', marker='.', linestyle='solid')
plt.legend()
plt.show()

# %%
import sys
print(sys.path.append('home/sanghwan/.local/lib/python2.7/site-packages/sympy/'))
# Out:
# None

# %%
f, axes=plt.subplots(1,2)
a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'pos', 'disk')
b=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/yesdarkmatter/snapshot_090', 'vel', 'disk')
a=sorted(a, key=lambda x:x[0])
a=np.array(a)
#b=sorted(b, key=lambda x:x[1])
b=np.array(b)
axes[0].plot(a[0:,0], b[0:,1])

c=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'pos', 'disk')
d=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/nodarkmatter/snapshot_090', 'vel', 'disk')
c=sorted(c, key=lambda x:x[0])
c=np.array(c)
d=sorted(d, key=lambda x:x[1])
d=np.array(d)
axes[1].plot(c[0:,0], d[0:,1])
plt.show()

# %%
for j in range(100,100) : 
    Y=j
    print('숫자는 %d' %Y)

# %% [markdown]
# a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output12/snapshot_000', 'pos', 'disk')
# for i in range(0,1000): #20000 in total
#     Y=i
#     plt.scatter(a[Y,0],a[Y,1], color='r', marker='.', s=10)
# a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output12/snapshot_000', 'pos', 'dm')
# for i in range(0,1000): #40000 in total
#     Y=i
#     plt.scatter(a[Y,0],a[Y,1], color='k', marker='.', s=1)
# plt.savefig('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output12/test.png')

# %% [markdown]
# """"fig, ax = plt.subplots()
# ax.set_xlim(-150,150);
# ax.set_ylim(-100,100);
# x,y=[],[]
# line, =plt.plot([],[], 'bo')
# def init():
#     line.set_data([], [])
#     return (line,)
# def animate(i):
#     a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output12/snapshot_00%d'%i, 'pos', 'disk')
#     x=a[0:,0]
#     y=a[0:,1]
#     line.set_data(x,y)
#     return (line,)
# anim=animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)
# rc('animation',html='html5')
# anim

# %%
a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output14/snapshot_090', 'pos', 'disk')
print(a)
print(a[0:,0]) #first column
# Out:
# [[-16.710491    6.9502687  14.044246 ]
#  [-17.185476    7.84047    11.338657 ]
#  [-15.575367    7.4698844  11.691021 ]
#  ...
#  [-18.346737  -20.829147    7.1311216]
#  [-19.610588  -20.299995    6.246621 ]
#  [-24.100582  -17.53776     8.521734 ]]
# [-16.710491 -17.185476 -15.575367 ... -18.346737 -19.610588 -24.100582]

# %%
print(a[0:,1]) #second column
# Out:
# [ 50.021404   8.764378   9.179629 ... -27.563643 -29.524387 -29.20492 ]

# %%
print(a[0:,2]) #third column
# Out:
# [18.466516    0.04952973 -0.55073696 ...  0.66994435  1.8005631
#   0.76973104]

# %%
plt.plot(a[0:,0],a[0:,1], ','); #argument , 'o' makes plot dotted

# %%
from matplotlib.animation import FuncAnimation
fig = plt.figure()

line = plt.plot([], [],
                color='skyblue',
                marker=',', markerfacecolor='red',
                markersize=2, linestyle='')[0]
plt.xlim(-100, 100)
plt.ylim(-100, 100)

list_x = []
list_y = []
def update(i):
    a=readsnap('/home/sanghwan/simul/Gadget-2.0.7/run1/Gadget2/galaxy/output17/snapshot_04%d'%i, 'pos', 'disk')
    list_x.append(a[0:,0])
    list_y.append(a[0:,1])
    line.set_data(list_x, list_y)
c=np.arange(0,10)
graph_ani = animation.FuncAnimation(fig=fig, func=update, frames=[1,2,3,4,5])
#graph_ani = FuncAnimation(fig=fig, func=update, frames=c)
#graph_ani.save('./graph_ani.gif', writer='ffmpeg', fps=3, dpi=100)
#FuncAnimation(fig, update, c)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-5f0a00935ceb> in <module>()
#      22 #FuncAnimation(fig, update, c)
#      23 #plt.show()
# ---> 24 plt.plot(update[1])
#
# TypeError: 'function' object has no attribute '__getitem__'

# %% [markdown]
# import matplotlib.pyplot as plt
# from matplotlib.animation import FuncAnimation
#
# fig = plt.figure()
#
# line = plt.plot([], [],
#                 color='skyblue',
#                 marker='o', markerfacecolor='blue',
#                 markersize=6)[0]
# plt.xlim(0, 6)
# plt.ylim(10, 16)
#
# list_x = []
# list_y = []
# def update(x_coordinate):
#     list_x.append(x_coordinate)
#     list_y.append(x_coordinate + 10)
#
#     line.set_data(list_x, list_y)
#
# graph_ani = FuncAnimation(fig=fig, func=update, frames=[1, 2, 3, 4, 5])
# graph_ani.save('graph_ani.gif', writer='imagemagick', fps=3, dpi=100)
#
# plt.show()

# %%
x=np.linspace(1, 10000000, 10000)
y=(73/1250*(np.sin(0.0001*x))**2) + (0.033399*(np.sin(0.0125*x)/4)**2)
plt.plot(x,y)
plt.xlim(0,50000)
# Out:
# (0, 50000)
